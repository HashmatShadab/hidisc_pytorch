# %%
data = [
    {"Epoch": 5000,
     "Patch": {"Acc": 78.719, "MCA": 77.378, "T2": 92.571, "T3": 96.391, "MAP": 82.647},
     "Slide": {"Acc": 85.214, "MCA": 84.225, "T2": 95.719, "T3": 98.443, "MAP": 90.523},
     "Patient": {"Acc": 85, "MCA": 86.767, "T2": 96.667, "T3": 96.667, "MAP": 91.934}},

    {"Epoch": 10000,
     "Patch": {"Acc": 80.369, "MCA": 79.157, "T2": 92.944, "T3": 96.587, "MAP": 85.289},
     "Slide": {"Acc": 86.381, "MCA": 85.688, "T2": 96.109, "T3": 98.054, "MAP": 91.603},
     "Patient": {"Acc": 85, "MCA": 86.897, "T2": 96.667, "T3": 96.667, "MAP": 91.938}},

    {"Epoch": 15000,
     "Patch": {"Acc": 79.727, "MCA": 78.094, "T2": 92.66, "T3": 96.19, "MAP": 84.489},
     "Slide": {"Acc": 85.214, "MCA": 83.96, "T2": 95.33, "T3": 98.443, "MAP": 90.533},
     "Patient": {"Acc": 85, "MCA": 86.897, "T2": 96.667, "T3": 96.667, "MAP": 91.021}},

    {"Epoch": 20000,
     "Patch": {"Acc": 79.814, "MCA": 78.155, "T2": 92.982, "T3": 96.477, "MAP": 84.824},
     "Slide": {"Acc": 84.436, "MCA": 82.682, "T2": 95.712, "T3": 97.665, "MAP": 91.63},
     "Patient": {"Acc": 85, "MCA": 86.897, "T2": 96.667, "T3": 96.667, "MAP": 92.612}},

    {"Epoch": 25000,
     "Patch": {"Acc": 79.784, "MCA": 77.769, "T2": 92.877, "T3": 96.52, "MAP": 84.767},
     "Slide": {"Acc": 83.268, "MCA": 81.203, "T2": 96.887, "T3": 98.443, "MAP": 90.518},
     "Patient": {"Acc": 83.333, "MCA": 85.469, "T2": 96.667, "T3": 96.667, "MAP": 91.451}},

    {"Epoch": 30000,
     "Patch": {"Acc": 79.86, "MCA": 77.717, "T2": 92.662, "T3": 96.225, "MAP": 84.914},
     "Slide": {"Acc": 83.657, "MCA": 81.608, "T2": 96.498, "T3": 98.443, "MAP": 91.013},
     "Patient": {"Acc": 85, "MCA": 86.897, "T2": 96.667, "T3": 96.667, "MAP": 91.641}},

    {"Epoch": 35000,
     "Patch": {"Acc": 79.968, "MCA": 77.807, "T2": 92.828, "T3": 96.335, "MAP": 84.998},
     "Slide": {"Acc": 83.268, "MCA": 81.079, "T2": 96.498, "T3": 98.443, "MAP": 90.935},
     "Patient": {"Acc": 85, "MCA": 86.897, "T2": 96.667, "T3": 96.667, "MAP": 91.244}},

    {"Epoch": 40000,
     "Patch": {"Acc": 80.06, "MCA": 77.893, "T2": 92.93, "T3": 96.36, "MAP": 84.926},
     "Slide": {"Acc": 83.268, "MCA": 81.079, "T2": 96.887, "T3": 98.443, "MAP": 90.755},
     "Patient": {"Acc": 85, "MCA": 86.897, "T2": 96.667, "T3": 96.667, "MAP": 91.31}}
]

# %%
import pandas as pd

# Converting the list of dictionary to flattened DataFrame
data_flat = []

for entry in data:
    for category in ["Patch", "Slide", "Patient"]:
        for metric, value in entry[category].items():
            data_flat.append({"Epoch": entry["Epoch"], "Category": category, "Metric": metric, "Value": value})

df = pd.DataFrame(data_flat)

print(df)
# Out:
#      Epoch Category Metric   Value
# 0     5000    Patch    Acc  78.719
# 1     5000    Patch    MCA  77.378
# 2     5000    Patch     T2  92.571
# 3     5000    Patch     T3  96.391
# 4     5000    Patch    MAP  82.647
# ..     ...      ...    ...     ...
# 115  40000  Patient    Acc  85.000
# 116  40000  Patient    MCA  86.897
# 117  40000  Patient     T2  96.667
# 118  40000  Patient     T3  96.667
# 119  40000  Patient    MAP  91.310
#
# [120 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assume 'df' is your DataFrame
sns.set_style("whitegrid")

metrics = df['Metric'].unique()

# Determine the number of rows needed for the plot
num_rows = len(metrics) // 2 + len(metrics) % 2

plt.figure(figsize=(14, num_rows * 7))

for i, metric in enumerate(metrics, 1):
    plt.subplot(num_rows, 2, i)
    df_subset = df[df['Metric'] == metric]
    sns.lineplot(x='Epoch', y='Value', hue='Category', data=df_subset)
    plt.title(metric)

# Title for the entire plot
plt.suptitle("Performance Metric for HiDisc-Patient", fontsize=16)
plt.tight_layout()
# save the plot
plt.savefig('performance_metric_for_hidisc_patient_bs_16.png')
plt.show()

# %%
data = [
    {"Epoch": 5999,
     "Patch": {"Acc": 82.11, "MCA": 81.214, "T2": 92.819, "T3": 96.419, "MAP": 86.687},
     "Slide": {"Acc": 87.54, "MCA": 86.978, "T2": 96.887, "T3": 98.443, "MAP": 93.824},
     "Patient": {"Acc": 86.667, "MCA": 86.484, "T2": 96.667, "T3": 98.333, "MAP": 94.473}},

    {"Epoch": 9999,
     "Patch": {"Acc": 82.585, "MCA": 81.753, "T2": 93.31, "T3": 96.573, "MAP": 87.09},
     "Slide": {"Acc": 86.77, "MCA": 85.758, "T2": 96.887, "T3": 98.054, "MAP": 92.63},
     "Patient": {"Acc": 88.33, "MCA": 89.783, "T2": 96.667, "T3": 98.333, "MAP": 92.99}},

    {"Epoch": 15999,
     "Patch": {"Acc": 81.560, "MCA": 80.687, "T2": 92.568, "T3": 96.03, "MAP": 86.043},
     "Slide": {"Acc": 86.770, "MCA": 86.341, "T2": 96.498, "T3": 97.665, "MAP": 92.587},
     "Patient": {"Acc": 86.667, "MCA": 88.196, "T2": 96.667, "T3": 98.333, "MAP": 92.340}},

    {"Epoch": 19999,
     "Patch": {"Acc": 82.181, "MCA": 81.048, "T2": 92.787, "T3": 96.682, "MAP": 86.366},
     "Slide": {"Acc": 86.381, "MCA": 85.19, "T2": 95.330, "T3": 98.443, "MAP": 92.887},
     "Patient": {"Acc": 86.667, "MCA": 88.196, "T2": 95.0, "T3": 98.333, "MAP": 93.389}},


    {"Epoch": 29999,
     "Patch": {"Acc": 82.582, "MCA": 81.477, "T2": 92.479, "T3": 96.054, "MAP": 87.356},
     "Slide": {"Acc": 86.770, "MCA": 84.764, "T2": 96.887, "T3": 98.883, "MAP": 94.170},
     "Patient": {"Acc": 88.333, "MCA": 88.225, "T2": 96.667, "T3": 98.333, "MAP": 95.213}},

    {"Epoch": 35999,
     "Patch": {"Acc": 82.085 , "MCA": 80.671, "T2": 92.908, "T3": 96.373, "MAP": 86.667},
     "Slide": {"Acc": 88.326, "MCA": 87.536, "T2": 96.887, "T3": 98.443, "MAP": 93.615},
     "Patient": {"Acc": 86.667, "MCA": 88.484, "T2": 96.667, "T3": 98.333, "MAP": 93.744}},

]

import pandas as pd

# Converting the list of dictionary to flattened DataFrame
data_flat = []

for entry in data:
    for category in ["Patch", "Slide", "Patient"]:
        for metric, value in entry[category].items():
            data_flat.append({"Epoch": entry["Epoch"], "Category": category, "Metric": metric, "Value": value})

df = pd.DataFrame(data_flat)

import matplotlib.pyplot as plt
import seaborn as sns

# Assume 'df' is your DataFrame
sns.set_style("whitegrid")

metrics = df['Metric'].unique()

# Determine the number of rows needed for the plot
num_rows = len(metrics) // 2 + len(metrics) % 2

plt.figure(figsize=(14, num_rows * 7))

for i, metric in enumerate(metrics, 1):
    plt.subplot(num_rows, 2, i)
    df_subset = df[df['Metric'] == metric]
    sns.lineplot(x='Epoch', y='Value', hue='Category', data=df_subset)
    plt.title(metric)

# Title for the entire plot
plt.suptitle("Performance Metric for HiDisc-Patient", fontsize=16)
plt.tight_layout()
# save the plot
plt.savefig('performance_metric_for_hidisc_patient_bs_10_roba.png')
plt.show()

# %%
import timm

# %%
timm.list_models()
#wide_resnet50_2
# Out:
# ['bat_resnext26ts',
#  'beit_base_patch16_224',
#  'beit_base_patch16_384',
#  'beit_large_patch16_224',
#  'beit_large_patch16_384',
#  'beit_large_patch16_512',
#  'beitv2_base_patch16_224',
#  'beitv2_large_patch16_224',
#  'botnet26t_256',
#  'botnet50ts_256',
#  'caformer_b36',
#  'caformer_m36',
#  'caformer_s18',
#  'caformer_s36',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384',
#  'cait_xxs24_224',
#  'cait_xxs24_384',
#  'cait_xxs36_224',
#  'cait_xxs36_384',
#  'coat_lite_medium',
#  'coat_lite_medium_384',
#  'coat_lite_mini',
#  'coat_lite_small',
#  'coat_lite_tiny',
#  'coat_mini',
#  'coat_small',
#  'coat_tiny',
#  'coatnet_0_224',
#  'coatnet_0_rw_224',
#  'coatnet_1_224',
#  'coatnet_1_rw_224',
#  'coatnet_2_224',
#  'coatnet_2_rw_224',
#  'coatnet_3_224',
#  'coatnet_3_rw_224',
#  'coatnet_4_224',
#  'coatnet_5_224',
#  'coatnet_bn_0_rw_224',
#  'coatnet_nano_cc_224',
#  'coatnet_nano_rw_224',
# ...

# %%
import torch
model = timm.create_model('wide_resnet50_2', pretrained=False, num_classes=0, global_pool='')
img = torch.randn(1, 3, 224, 224)
model(img).shape
# Out:
# torch.Size([1, 2048, 7, 7])

# %%
# for resnet50
model = timm.create_model('resnet50', pretrained=False, num_classes=0, global_pool='')
img = torch.randn(1, 3, 224, 224)
model(img).shape
# Out:
# torch.Size([1, 2048, 7, 7])
